# %%
data = {'name': 'cpu', 'columns': ['time', 'usage_guest', 'usage_iowait'], 'values': [['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.005003502450607419], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0], ['2021-03-24T08:16:30Z', 0.0, 0.0]]}
print(data)
# Out:
# {'name': 'cpu', 'columns': ['time', 'usage_guest', 'usage_iowait'], 'values': [['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:10Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:20Z', 0.0, 0.0], ['2021-03-24T08:16:
# ...

# %%
import numpy as np

#print(data['values'])
a = np.hstack(data['values'])
#print(a)
#a = np.concatenate(data['values'], axis=None)
b = np.reshape(a, (-1, 3))
print(b.T[0])
# Out:
# ['2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z' '2021-03-24T08:16:10Z'
#  '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z'
#  '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z'
#  '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z'
#  '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z'
#  '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z'
#  '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z' '2021-03-24T08:16:20Z'
# ...
